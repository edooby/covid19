# %% [markdown]
# ## Récupération des statistiques par pays
# - via l'API https://api.covid19api.com/summary

# %%
import requests
import json

# Récupération des stats par pays
def stat_country(country):
    url = 'https://api.covid19api.com/summary'
    response = requests.get(url)
    data = response.json()
    for c in data['Countries']:
         if c['Country']== country:
            print("#### ", country, " ####")
            print("Nouveaux cas confirmés en 24h : ", c['NewConfirmed'] )
            print("Total nombre de cas: ", c['TotalConfirmed'])
            print("Nombre de nouveau décès en 24h: ", c['NewDeaths'])
            print("Nombre de total de décès: ", c['TotalDeaths'])
            print("\n")

# %% [markdown]
# ## Exemple de résultats sur les pays : France, Italie, Espagne

# %%
stat_country('France')
stat_country('Italy')
stat_country('Spain')
# Out:
# ####  France  ####
# Nouveaux cas confirmés en 24h :  3951
# Total nombre de cas:  29551
# Nombre de nouveau décès en 24h:  365
# Nombre de total de décès:  1698
#
#
# ####  Italy  ####
# Nouveaux cas confirmés en 24h :  6203
# Total nombre de cas:  80589
# Nombre de nouveau décès en 24h:  712
# Nombre de total de décès:  8215
#
#
# ####  Spain  ####
# Nouveaux cas confirmés en 24h :  8271
# Total nombre de cas:  57786
# Nombre de nouveau décès en 24h:  718
# Nombre de total de décès:  4365

# %% [markdown]
# ## Récupération des données de cas confirmés par pays
# - via l'api https://api.covid19api.com/total/country/spain/confirmed

# %%
def total_case_confirmed_by_country(country):
    url = "https://api.covid19api.com/total/country/"+ country + "/status/confirmed"
    response = requests.get(url)
    data = response.json()
    confirmed = []
    for d in data:
        last = d['Cases']
        confirmed.append(last)
    return confirmed

# %% [markdown]
# ## Exemple d'utilisation graphique
# - sans décalage pour la France

# %%
plt.plot(total_case_confirmed_by_country("France"), label='France')
plt.plot(total_case_confirmed_by_country("Italy"), label='Italy')
plt.plot(total_case_confirmed_by_country("Spain"), label='Spain')
#plt.plot(total_case_confirmed_by_country("US"), label='US')
#plt.plot(total_case_confirmed_by_country("China"), label='China')
plt.ylabel('Nombre de cas confirmés')
plt.xlabel('JOURS')
plt.legend()
plt.show()

# %% [markdown]
# ## Récupération des données de nouveaux cas confirmés par pays
# - via l'api https://api.covid19api.com/total/country/spain/confirmed

# %%
def new_case_confirmed_by_country_per_day(country):
    url = "https://api.covid19api.com/total/country/"+ country + "/status/confirmed"
    response = requests.get(url)
    data = response.json()
    nb_case = 0
    cpt = 0
    confirmed = []
    for d in data:
        cpt = cpt+1
        last = d['Cases']
        new = last - nb_case
        nb_case = last
    
        confirmed.append(new)
    return confirmed

# %% [markdown]
# ## Exemple d'utilisation graphique
# - sans décalage de données pour la France

# %%
plt.plot(new_case_confirmed_by_country_per_day("France"), label='France')
plt.plot(new_case_confirmed_by_country_per_day("Italy"), label='Italy')
plt.plot(new_case_confirmed_by_country_per_day("Spain"), label='Spain')
plt.ylabel('Nombre de nouveaux confirmés')
plt.xlabel('JOURS')
plt.legend()
plt.show()

# %% [markdown]
# - Avec 11 jours de décalage pour la France pour affiner la tendance avec les deux autres pays

# %%
plt.plot(new_case_confirmed_by_country_per_day("France")[10:], label='France + 11 jours')
plt.plot(new_case_confirmed_by_country_per_day("Italy"), label='Italy')
plt.plot(new_case_confirmed_by_country_per_day("Spain"), label='Spain')
plt.ylabel('Nombre de nouveaux confirmés')
plt.xlabel('JOURS')
plt.legend()
plt.show()

# %% [markdown]
# ## Récupération des décès totaux par pays

# %%
def total_case_death_by_country(country):
    url = "https://api.covid19api.com/total/country/"+ country + "/status/deaths"
    response = requests.get(url)
    data = response.json()
    deaths = []
    for d in data:
        last = d['Cases']
        deaths.append(last)
    return deaths

# %% [markdown]
# ## Exemple d'utilisation graphique
# - sans décalage pour la france

# %%
plt.plot(total_case_death_by_country("France")[10:], label='France')
plt.plot(total_case_death_by_country("Italy"), label='Italy')
plt.plot(total_case_death_by_country("Spain"), label='Spain')
#plt.plot(total_case_death_by_country("US"), label='US')
plt.ylabel('Nombre de décès')
plt.xlabel('JOURS')
plt.legend()
plt.show()

# %% [markdown]
# ## Récupération des données de nouveaux décès par pays
# - via l'API https://api.covid19api.com/total/country/spain/status/deaths

# %%
def new_case_death_by_country_per_day(country):
    url = "https://api.covid19api.com/total/country/"+ country + "/status/deaths"
    response = requests.get(url)
    data = response.json()
    nb_case = 0
    cpt = 0
    deaths=[]
    for d in data:
        cpt = cpt
        last = d['Cases']
        new = last - nb_case
        nb_case = last
        deaths.append(new)
    return deaths

# %% [markdown]
# ## Exemple d'utilisation graphique
# - avec décalage de 11 jours pour la France

# %%
# affichage des 3 courbes décés : France, Italie, Espagne
plt.plot(new_case_death_by_country_per_day("France")[10:], label='France + 11 jours')
plt.plot(new_case_death_by_country_per_day("Italy"), label='Italy')
plt.plot(new_case_death_by_country_per_day("Spain"), label='Spain')
plt.ylabel('Nombre de nouveaux décès')
plt.xlabel('JOURS')
plt.legend()
plt.show()

# %% [markdown]
# ## Comparaison avec la Chine

# %%
stat_country('China')
# Out:
# ####  China  ####
# Nouveaux cas confirmés en 24h :  121
# Total nombre de cas:  81782
# Nombre de nouveau décès en 24h:  6
# Nombre de total de décès:  3291

# %%
plt.plot(new_case_death_by_country_per_day("China"), label='China')
plt.plot(new_case_death_by_country_per_day("Italy")[19:], label='Italy')
plt.plot(new_case_death_by_country_per_day("Spain")[19:], label='Spain')
plt.plot(new_case_death_by_country_per_day("France")[30:], label='France')
#plt.plot(new_case_death_by_country_per_day("US")[30:], label='US')
plt.ylabel('Nombre de nouveaux décès')
plt.xlabel('JOURS')
plt.legend()
plt.show()

# %%
plt.plot(total_case_death_by_country("China"), label='China')
#plt.plot(total_case_death_by_country("US")[40:], label='US')
plt.plot(total_case_death_by_country("Italy")[19:], label='Italy')
plt.plot(total_case_death_by_country("Spain")[19:], label='Spain')
plt.plot(total_case_death_by_country("France")[30:], label='France')
plt.ylabel('Nombre de décès')
plt.xlabel('JOURS')
plt.legend()
plt.show()

# %% [markdown]
# Sur ce dernier graphique, on se rend bien compte que les courbes de l'Italie, l'Espagne et la France ont exactement les mêmes tendances. La courbe de la Chine a atteint une phase de stabilisation, même si l'on n'a quelques nouveaux cas encore.

# %% [markdown]
# ## Récupération data France
# - via api : https://api.covid19api.com/all

# %%
import pandas as pd
import numpy as np

def data_country(country):
    url = 'https://api.covid19api.com/all'
    response = requests.get(url)
    data = response.json()
    confirm =[]
    deaths = []
    recover= []
    index =[]
    cpt=0
    country_df = pd.DataFrame(columns=['Country', 'Province', 'Lat', 'Lon', 'Date', 'Cases', 'Status'])
    for c in data:
        if c['Country']== country:
            cpt+=1
            index.append(cpt)
            dfc = pd.DataFrame(c, index=[cpt], columns=['Country', 'Province', 'Lat', 'Lon', 'Date', 'Cases', 'Status'])
            country_df =  pd.concat([country_df, dfc])
            if c['Status']=="confirmed":
                confirm.append(c['Cases'])
            if c['Status']=="deaths":
                deaths.append(c['Cases'])
            if c['Status']=="recovered":
                recover.append(c['Cases'])
    return country_df

# %%
data_country("France")
# Out:
#     Country          Province      Lat      Lon                  Date  Cases  \
# 1    France                          0        0  2020-01-24T00:00:00Z      2
# 2    France                          0        0  2020-01-24T00:00:00Z      0
# 3    France                          0        0  2020-01-24T00:00:00Z      0
# 4    France                          0        0  2020-01-25T00:00:00Z      3
# 5    France                          0        0  2020-01-25T00:00:00Z      0
# 6    France                          0        0  2020-01-25T00:00:00Z      0
# 7    France                          0        0  2020-01-26T00:00:00Z      3
# 8    France                          0        0  2020-01-26T00:00:00Z      0
# 9    France                          0        0  2020-01-26T00:00:00Z      0
# 10   France                          0        0  2020-01-27T00:00:00Z      3
# 11   France                          0        0  2020-01-27T00:00:00Z      0
# 12   France                          0        0  2020-01-27T00:00:00Z      0
# 13   France                          0        0  2020-01-28T00:00:00Z      4
# 14   France                          0        0  2020-01-28T00:00:00Z      0
# 15   France                          0        0  2020-01-28T00:00:00Z      0
# 16   France                          0        0  2020-01-29T00:00:00Z      5
# 17   France                          0        0  2020-01-29T00:00:00Z      0
# 18   France                          0        0  2020-01-29T00:00:00Z      0
# 19   France                          0        0  2020-01-30T00:00:00Z      5
# 20   France                          0        0  2020-01-30T00:00:00Z      0
# 21   France                          0        0  2020-01-30T00:00:00Z      0
# 22   France                          0        0  2020-01-31T00:00:00Z      5
# 23   France                          0        0  2020-01-31T00:00:00Z      0
# 24   France                          0        0  2020-01-31T00:00:00Z      0
# 25   France                          0        0  2020-02-01T00:00:00Z      6
# 26   France                          0        0  2020-02-01T00:00:00Z      0
# 27   France                          0        0  2020-02-01T00:00:00Z      0
# 28   France                          0        0  2020-02-02T00:00:00Z      6
# 29   France                          0        0  2020-02-02T00:00:00Z      0
# 30   France                          0        0  2020-02-02T00:00:00Z      0
# ..      ...               ...      ...      ...                   ...    ...
# 505  France         St Martin  18.0708 -63.0501  2020-03-27T00:00:00Z     11
# 506  France         St Martin  18.0708 -63.0501  2020-03-27T00:00:00Z      0
# 507  France         St Martin  18.0708 -63.0501  2020-03-27T00:00:00Z      0
# 508  France     French Guiana        4      -53  2020-03-27T00:00:00Z     28
# 509  France     French Guiana        4      -53  2020-03-27T00:00:00Z      6
# 510  France     French Guiana        4      -53  2020-03-27T00:00:00Z      0
# 511  France  French Polynesia -17.6797 -149.407  2020-03-27T00:00:00Z     30
# 512  France  French Polynesia -17.6797 -149.407  2020-03-27T00:00:00Z      0
# 513  France  French Polynesia -17.6797 -149.407  2020-03-27T00:00:00Z      0
# 514  France        Guadeloupe   16.265  -61.551  2020-03-27T00:00:00Z     73
# 515  France        Guadeloupe   16.265  -61.551  2020-03-27T00:00:00Z      0
# 516  France        Guadeloupe   16.265  -61.551  2020-03-27T00:00:00Z      1
# 517  France        Martinique  14.6415 -61.0242  2020-03-27T00:00:00Z     81
# 518  France        Martinique  14.6415 -61.0242  2020-03-27T00:00:00Z      0
# 519  France        Martinique  14.6415 -61.0242  2020-03-27T00:00:00Z      1
# 520  France           Mayotte -12.8275  45.1662  2020-03-27T00:00:00Z     50
# 521  France           Mayotte -12.8275  45.1662  2020-03-27T00:00:00Z      0
# 522  France           Mayotte -12.8275  45.1662  2020-03-27T00:00:00Z      0
# 523  France     New Caledonia -20.9043  165.618  2020-03-27T00:00:00Z     15
# 524  France     New Caledonia -20.9043  165.618  2020-03-27T00:00:00Z      0
# 525  France     New Caledonia -20.9043  165.618  2020-03-27T00:00:00Z      0
# 526  France                    46.2276   2.2137  2020-03-27T00:00:00Z  32964
# 527  France                    46.2276   2.2137  2020-03-27T00:00:00Z   5700
# 528  France                    46.2276   2.2137  2020-03-27T00:00:00Z   1995
# 529  France           Reunion -21.1151  55.5364  2020-03-27T00:00:00Z    145
# 530  France           Reunion -21.1151  55.5364  2020-03-27T00:00:00Z      1
# 531  France           Reunion -21.1151  55.5364  2020-03-27T00:00:00Z      0
# 532  France  Saint Barthelemy     17.9 -62.8333  2020-03-27T00:00:00Z      5
# 533  France  Saint Barthelemy     17.9 -62.8333  2020-03-27T00:00:00Z      0
# 534  France  Saint Barthelemy     17.9 -62.8333  2020-03-27T00:00:00Z      0
#
#         Status
# 1    confirmed
# 2    recovered
# 3       deaths
# 4    confirmed
# 5    recovered
# 6       deaths
# 7    confirmed
# 8    recovered
# 9       deaths
# 10   confirmed
# 11   recovered
# 12      deaths
# 13   confirmed
# 14   recovered
# 15      deaths
# 16   confirmed
# 17   recovered
# 18      deaths
# 19   confirmed
# 20   recovered
# 21      deaths
# 22   confirmed
# 23   recovered
# 24      deaths
# 25   confirmed
# 26   recovered
# 27      deaths
# 28   confirmed
# 29   recovered
# 30      deaths
# ..         ...
# 505  confirmed
# 506  recovered
# 507     deaths
# 508  confirmed
# 509  recovered
# 510     deaths
# 511  confirmed
# 512  recovered
# 513     deaths
# 514  confirmed
# 515  recovered
# 516     deaths
# 517  confirmed
# 518  recovered
# 519     deaths
# 520  confirmed
# 521  recovered
# 522     deaths
# 523  confirmed
# 524  recovered
# 525     deaths
# 526  confirmed
# 527  recovered
# 528     deaths
# 529  confirmed
# 530  recovered
# 531     deaths
# 532  confirmed
# 533  recovered
# 534     deaths
#
# [534 rows x 7 columns]
